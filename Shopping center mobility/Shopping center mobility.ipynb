# %% [markdown]
# # Mobility in shopping centers during COVID-19 crisis

# %% [markdown]
# Many malls had to close their doors to costumers in order to prevent the spread of coronavirus from worsening. But these measures were heterogeneous within Brazil, some states already allowed shopping centers and others nonessential business to reopen whereas they are still closed in anothers.
#
# This study aims to show how different open companies in brazilian real state (BR Malls and Iguatemi) are suffering during the pandemic by using scrapped Google Maps mobility data.
#
# For a better experience, see this notebook [here](https://nbviewer.jupyter.org/github/gustal/portfolio/blob/master/Shopping%20center%20mobility/Shopping%20center%20mobility.ipynb)

# %% [markdown]
# ### Importing libraries and built-in functions

# %%
# =============================================================================
# Importing libraries
# =============================================================================

# Data handling
import pandas as pd
import numpy as np

# SQL
from sqlalchemy import create_engine

# Visualization
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from matplotlib import gridspec
import seaborn as sns

plt.style.use('fivethirtyeight') # Setting default visualization

# Dates
from datetime import datetime as dt

ct_date = dt.today().strftime("%m-%d-%y")
dts = pd.date_range(start = '03-27-2020', end = ct_date, freq = 'D').strftime("%m_%d_%y")

# Others
from IPython.display import HTML
from tqdm.notebook import tqdm_notebook, tqdm
from math import ceil

# =============================================================================
# Built-in functions
# =============================================================================

# 
def byHour(tbdict, company, day):
    
    ''' Aggregate data by hour '''
    
    day_of_week = {
        0:'segunda',
        1:'terça',
        2:'quarta',
        3:'quinta',
        4:'sexta',
        5:'sabado',
        6:'domingo'
    }
    
    output_live1 = tbdict[company]\
        .assign(time_collected_day = lambda x: x.time_collected.dt.strftime('%Y-%m-%d'), popular = lambda x: x.popular.apply(pd.to_numeric))\
        .query('live == 1 and time_collected_day == @day')\
        .pivot_table(index = 'place', columns = 'hour_text', values = 'popular')
    
    dayofweek = day_of_week.get(pd.to_datetime(day).dayofweek)
    
    output_live0 = tbdict[company]\
        .assign(time_collected_day = lambda x: x.time_collected.dt.strftime('%Y-%m-%d'), popular = lambda x: x.popular.apply(pd.to_numeric))\
        .query('live == 0 and time_collected_day == @day and day == @dayofweek')\
        .pivot_table(index = 'place', columns = 'hour_text', values = 'popular')
    
    return output_live1, output_live0

# Occupation rate
def occupationRate(tbdict, key, shoppings):
    
    ''' This function computes occupation rate for each mall of a given company '''
    
    day_of_week = {
        0:'segunda',
        1:'terça',
        2:'quarta',
        3:'quinta',
        4:'sexta',
        5:'sabado',
        6:'domingo'
    }
    
    tbdict[key] = tbdict[key].assign(popular = lambda x: x.popular.apply(pd.to_numeric))
    
    # Usual and atual data
    s0_temp = []
    for index, row in tbdict[key].query('live == 0').assign(dow = lambda x: x.time_collected.dt.dayofweek.apply(day_of_week.get)).iterrows():
        if row.day == row.dow:
            s0_temp.append(row)
    s0 = pd.concat(s0_temp, axis = 1).T.assign(popular = lambda x: x.popular.apply(pd.to_numeric))\
            .pivot_table(index = 'place', columns = [pd.Grouper(key = 'time_collected', freq = 'D'), 'hour_text'], values = 'popular')
    
    s1 = tbdict[key].query('live == 1').pivot_table(index = 'place', columns = [pd.Grouper(key = 'time_collected', freq = 'D'), 'hour_text'], values = 'popular')
    
    temp = s1.div(s0).T.query('time_collected >= @pd.to_datetime("2020-04-28")')\
            .reset_index().replace([np.inf, -np.inf], np.nan).groupby('time_collected').mean().T
        
    shop = shoppings.query('company == @key')[['local']].set_index('local')
    
    output = shop.merge(temp, left_index = True, right_index = True, how = 'outer')
        
    return output

def weightedMean(tb, path, name):
    
    ''' Computes the weighted average occupation rate for a given company '''
    
    merged = pd.read_excel(path)[['shopping', 'sales_419']]\
                .set_index(['shopping']).merge(tb, left_index = True, right_index = True)
    
    xx2 = merged.applymap(lambda x: True if not np.isnan(x) else False)\
                .apply(lambda x: merged.sales_419 * x).drop('sales_419', axis = 1)
    
    xx3 = merged.apply(lambda x: merged.sales_419 * x).drop('sales_419', axis = 1)
    
    output = pd.DataFrame(xx3.sum()).T / pd.DataFrame(xx2.sum()).T
    output.index = [name]
    
    return output

# %% [markdown]
# ### Loading files

# %%
# =============================================================================
# Loading files
# =============================================================================

# List of shopping centers for each company
iguatemi = pd.read_excel('D:/Projetos/google_maps/other_files/iguatemi_keys.xlsx')
brmalls = pd.read_excel('D:/Projetos/google_maps/other_files/brmalss_keys.xlsx')

shoppings = iguatemi[['local', 'place_id']].assign(company = 'iguatemi')\
                .append(brmalls[['local', 'place_id']].assign(company = 'brmalls')) # Appending the lists

# Market share by shooping center
iguatemi_receita_shopping_sales419 = pd.read_excel('D:/Projetos/google_maps/auxiliar/iguatemi_receita_shopping.xlsx')\
    .set_index('shopping')\
    .filter(['sales_419'])\
    .assign(sales_419 = lambda x: x['sales_419'] / x['sales_419'].sum() * 100)

brmalls_receita_shopping_sales419 = pd.read_excel('D:/Projetos/google_maps/auxiliar/brmalls_receita_shopping.xlsx')\
    .set_index('shopping')\
    .filter(['sales_419'])\
    .assign(sales_419 = lambda x: x['sales_419'] / x['sales_419'].sum() * 100)

# Loading from SQL files
tbs_query = []
for date in tqdm_notebook(dts):
    
    ''' Loading data for brMalls and Iguatemi shopping centers '''
    
    engine = create_engine(f'sqlite:///D:/Users/gusta/Documents/google_maps/databases/google_live_{date}.db')
    query_string = 'SELECT * from google_live WHERE place_id in (' + ', '.join(['"' + x + '"' for x in shoppings.place_id.tolist()]) + ')'
    temp = pd.read_sql_query(query_string, engine)
    tbs_query.append(temp)

tb = pd.concat(tbs_query, axis = 0).assign(time_collected = lambda x: x.time_collected.apply(pd.to_datetime))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=59.0), HTML(value='')))
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1247                     self.dialect.do_execute(
# -> 1248                         cursor, statement, parameters, context
#    1249                     )
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#
# OperationalError: no such table: google_live
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-4-09e190900511> in <module>
#      29     engine = create_engine(f'sqlite:///D:/Users/gusta/Documents/google_maps/databases/google_live_{date}.db')
#      30     query_string = 'SELECT * from google_live WHERE place_id in (' + ', '.join(['"' + x + '"' for x in shoppings.place_id.tolist()]) + ')'
# ---> 31     temp = pd.read_sql_query(query_string, engine)
#      32     tbs_query.append(temp)
#      33
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_sql_query(sql, con, index_col, coerce_float, params, parse_dates, chunksize)
#     330         coerce_float=coerce_float,
#     331         parse_dates=parse_dates,
# --> 332         chunksize=chunksize,
#     333     )
#     334
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize)
#    1216         args = _convert_params(sql, params)
#    1217
# -> 1218         result = self.execute(*args)
#    1219         columns = result.keys()
#    1220
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1085     def execute(self, *args, **kwargs):
#    1086         """Simple passthrough to SQLAlchemy connectable"""
# -> 1087         return self.connectable.execute(*args, **kwargs)
#    1088
#    1089     def read_table(
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    2189
#    2190         connection = self._contextual_connect(close_with_result=True)
# -> 2191         return connection.execute(statement, *multiparams, **params)
#    2192
#    2193     def scalar(self, statement, *multiparams, **params):
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in execute(self, object_, *multiparams, **params)
#     974         """
#     975         if isinstance(object_, util.string_types[0]):
# --> 976             return self._execute_text(object_, multiparams, params)
#     977         try:
#     978             meth = object_._execute_on_connection
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_text(self, statement, multiparams, params)
#    1149             parameters,
#    1150             statement,
# -> 1151             parameters,
#    1152         )
#    1153         if self._has_events or self.engine._has_events:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1286         except BaseException as e:
#    1287             self._handle_dbapi_exception(
# -> 1288                 e, statement, parameters, cursor, context
#    1289             )
#    1290
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1480             elif should_wrap:
#    1481                 util.raise_(
# -> 1482                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1483                 )
#    1484             else:
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     176
#     177         try:
# --> 178             raise exception
#     179         finally:
#     180             # credit to
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1246                 if not evt_handled:
#    1247                     self.dialect.do_execute(
# -> 1248                         cursor, statement, parameters, context
#    1249                     )
#    1250
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sqlalchemy\engine\default.py in do_execute(self, cursor, statement, parameters, context)
#     588
#     589     def do_execute(self, cursor, statement, parameters, context=None):
# --> 590         cursor.execute(statement, parameters)
#     591
#     592     def do_execute_no_params(self, cursor, statement, context=None):
#
# OperationalError: (sqlite3.OperationalError) no such table: google_live
# [SQL: SELECT * from google_live WHERE place_id in ("ChIJtb39eG1XzpQRrsiFJG_8XwA", "ChIJbUvzMdtQzpQRvllpLqTebC8", "ChIJnTmhmztYzpQRn_wmS6AGrS4", "ChIJKdzx_CACz5QR6TTipHDvhDs", "ChIJ4Wxq0XPPyJQR4RvPLfbSyfY", "ChIJqYHKoJ7FyJQRqTR37jRhRi0", "ChIJeRdL-2WKxZQRw-eJcKnXu28", "ChIJU1VVBTR3uJQRgRYNp9eHMlo", "ChIJv3rQSZu5uZQRWZ90ZPh2Bfs", "ChIJk5ltpp53GZURYk9cuiHLd5Q", "ChIJj4Er9_p4GZURoDiLODruMm4", "ChIJ9Y8QHpswWpMRzohd-1XpYt0", "ChIJCYspYXlDGZURlouRxtki5ns", "ChIJ1UVL_4Kp2JQRigaOvaUjEsQ", "ChIJR6tIJ9uDmQARYDz2YyfeSSE", "ChIJAQAsrmt-mQARtdN46KDhAwI", "ChIJ9yMkU1t9mQAR4x9nlVEeFSU", "ChIJqV0ajHsBz5QRzDrTKHAnKgI", "ChIJC6hfUKJFpJQR3V3RU2DYJNY", "ChIJeRuKjrIfqwcR5yWHecNi5YQ", "ChIJKZCIpy5azpQRpPbJYOYsCAQ", "ChIJb3Fzl9_IyJQRjTD2JBoItMY", "ChIJJ9U5gsOZpgARm7XyElrYV90", "ChIJv7RU7Wjk3JQR658Cc0Mmlk8", "ChIJI3BQHjtWzpQRXKu9QpuVCUg", "ChIJDbHASpXohpQRuIhWy6CrSXE", "ChIJu7uqcw2bmAARrENeOu2m_7Y", "ChIJCfWlcMlc65QR_h_yMZb3gKk", "ChIJs20TRCXxXpMRgx2tuyLDIBs", "ChIJRyOy8HDk3JQREPun8P4ZqYk", "ChIJ-SAk5Om8HpUR6YEgpCxgLG0", "ChIJH0y_vH4xxpQRzkuc5A5qxBQ", "ChIJVVUF6_hbzpQRFJgUeqwC1ic", "ChIJ_2XOfqhnmQARJUod2uMHfXE", "ChIJt3pFWfvW7JQRBDCzmw95Ta4", "ChIJQcmFCp0abJIRFSNJC3oNLxs", "ChIJaz4DGn6O9gcRvSHubbhBgmw", "ChIJp97V4mBCzpQRgcGdS8IxLSs", "ChIJCaD3K7eR9gcRxOiQ69fDhd4", "ChIJjwgFVvaPpgARxkTriIdETSo", "ChIJ2QEABZdBzpQRH1Prw3-FlAM", "ChIJUZzq_Q8WuAARERv2oWlz80k", "ChIJAQCAsMbzXpMRsKf5vNHpIIg")]
# (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
# =============================================================================
# Restructuring data
# =============================================================================

# Creating a dictionary - this will make it easier to call for specific data
tbdict = {
    'iguatemi':tb.query('place_id == @iguatemi.place_id.tolist()'),
    'brmalls':tb.query('place_id == @brmalls.place_id.tolist()')
}

# Getting occupation rate
iguatemi_ocpRate, brmalls_ocpRate = occupationRate(tbdict, 'iguatemi', shoppings), occupationRate(tbdict, 'brmalls', shoppings)

# % vendas por shopping
iguatemi_receita_shopping_sales419 = pd.read_excel('D:/Projetos/google_maps/auxiliar/iguatemi_receita_shopping.xlsx')\
    .set_index('shopping')\
    .filter(['sales_419'])\
    .assign(sales_419 = lambda x: x['sales_419'] / x['sales_419'].sum() * 100)

brmalls_receita_shopping_sales419 = pd.read_excel('D:/Projetos/google_maps/auxiliar/brmalls_receita_shopping.xlsx')\
    .set_index('shopping')\
    .filter(['sales_419'])\
    .assign(sales_419 = lambda x: x['sales_419'] / x['sales_419'].sum() * 100)

# %% [markdown]
# ### Charts
# Each company index is weighted by its shopping centers sales.

# %%
# =============================================================================
# Chart - Weighted mean occupation rate
# =============================================================================

# Computing the weighted mean for each company
iguatemi_weighted_mean = weightedMean(iguatemi_ocpRate, 'D:/Projetos/google_maps/auxiliar/iguatemi_receita_shopping.xlsx', 'Iguatemi')
brmalls_weighted_mean = weightedMean(brmalls_ocpRate, 'D:/Projetos/google_maps/auxiliar/brmalls_receita_shopping.xlsx', 'brMalls')
data_chart = brmalls_weighted_mean.append(iguatemi_weighted_mean).T

# Chart
fig = plt.figure(figsize = (8, 8))
fig.suptitle('Weighted mean mobility index for each company, daily data', fontsize=15, horizontalalignment = 'center', weight = 'bold')

# Grid
gs = gridspec.GridSpec(2, 1, height_ratios=[3, 1])
ax0 = plt.subplot(gs[0, 0])
ax1 = plt.subplot(gs[-1, 0])

(data_chart * 100).iloc[:, :].plot(ax = ax0, ylim = (0, 40))
(data_chart * 100).iloc[:, :].assign(Difference = lambda x: x['brMalls'] - x['Iguatemi']).plot(y = 'Difference', kind = 'bar', ax = ax1, ylim = (-20, 20), 
                                     color = 'lightgrey', edgecolor = 'black', linewidth = 1.5, label = 'Difference (brMalls - Iguatemi)')
# Set ticks every week
ax1.xaxis.set_major_locator(mdates.WeekdayLocator())
# Set major ticks format
ax1.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))

# Alignment: center
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
# }
# </style>

# %% [markdown]
# As one may expect there is high variance since we ploted daily data, although its pretty clear that brMalls was able to retain more of its mobility than Iguatemi.

# %%
# =============================================================================
# Chart - Weighted mean occupation rate, 7 days moving average
# =============================================================================

# 7 days moving average
fig, ax = plt.subplots(1, 1, figsize = (8, 4))
fig.suptitle('Shopping centers mobility, 7 days moving average', fontsize=15, horizontalalignment = 'center', weight = 'bold')
(data_chart * 100).iloc[:, :].rolling(7).mean().plot(ax = ax, ylim = (0, 40))

# %% [markdown]
# This is more noticeable after plotting the 7 days moving average of the same data.

# %% [markdown]
# ### Heatmap

# %% [markdown]
# ##### Iguatemi

# %%
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "6pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]
def color(val):
    if val == 0:
        return 'background-color: %s' % 'transparent'
    else:
        return ''
        

rename_cols = {x:x.strftime("%m/%d") for x in iguatemi_ocpRate.columns}
(iguatemi_receita_shopping_sales419.merge(iguatemi_ocpRate, left_index = True, right_index = True)\
    .reset_index()\
    .sort_values('sales_419', ascending = False)\
    .assign(sales_419 = lambda x: x.sales_419.apply("{0:.2f}%".format))\
    .rename(columns = {'sales_419':'% revenus'})\
    .set_index(['index', '% revenus']) * 100)\
    .iloc[:, :].rename(columns = rename_cols)\
    .fillna(0).style.background_gradient('coolwarm_r', axis=1, vmin = 0, vmax = 100)\
    .applymap(color)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Iguatemi")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_ecfce052_9d60_11ea_bccc_6432a86142f1 th {
#           font-size: 6pt;
#     }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1 td {
#           padding: 0em 0em;
#     }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1 th:hover {
#           font-size: 12pt;
#     }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col0 {
#             background-color:  #e16751;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col1 {
#             background-color:  #ea7b60;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col2 {
#             background-color:  #e26952;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col3 {
#             background-color:  #cd423b;
#             color:  #f1f1f1;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col4 {
#             background-color:  #dc5d4a;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col5 {
#             background-color:  #df634e;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col6 {
#             background-color:  #ee8468;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col7 {
#             background-color:  #e67259;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col8 {
#             background-color:  #ee8468;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col9 {
#             background-color:  #e57058;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col10 {
#             background-color:  #e36c55;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col11 {
#             background-color:  #e57058;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col12 {
#             background-color:  #be242e;
#             color:  #f1f1f1;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col13 {
#             background-color:  #e7745b;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col14 {
#             background-color:  #e8765c;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col15 {
#             background-color:  #e8765c;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col16 {
#             background-color:  #e36c55;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col17 {
#             background-color:  #e26952;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col18 {
#             background-color:  #df634e;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col19 {
#             background-color:  #d65244;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col20 {
#             background-color:  #e8765c;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col21 {
#             background-color:  #eb7d62;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col22 {
#             background-color:  #de614d;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col23 {
#             background-color:  #d95847;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col24 {
#             background-color:  #e26952;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row0_col25 {
#             background-color:  #ea7b60;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col3 {
#             background-color:  #ec7f63;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col4 {
#             background-color:  #ee8468;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col5 {
#             background-color:  #ef886b;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col6 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col7 {
#             background-color:  #f7aa8c;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col8 {
#             background-color:  #f6bfa6;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce052_9d60_11ea_bccc_6432a86142f1row1_col9 {
#             background-color:  #f18d6f;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_ecfce0

# %% [markdown]
# ##### brMalls

# %%
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "6pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

def color(val):
    if val == 0:
        return 'background-color: %s' % 'transparent'
    else:
        return ''

rename_cols = {x:x.strftime("%m/%d") for x in brmalls_ocpRate.columns}
(brmalls_receita_shopping_sales419.merge(brmalls_ocpRate, left_index = True, right_index = True)\
    .reset_index()\
    .sort_values('sales_419', ascending = False)\
    .assign(sales_419 = lambda x: x.sales_419.apply("{0:.2f}%".format))\
    .rename(columns = {'sales_419':'% revenues'})\
    .set_index(['shopping', '% revenues']) * 100)\
    .iloc[:, :].rename(columns = rename_cols)\
    .fillna(0).style.background_gradient('coolwarm_r', axis=1, vmin = 0, vmax = 100)\
    .applymap(color)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("brMalls")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style  type="text/css" >
#     #T_183d790a_9d61_11ea_82cf_6432a86142f1 th {
#           font-size: 6pt;
#     }    #T_183d790a_9d61_11ea_82cf_6432a86142f1 td {
#           padding: 0em 0em;
#     }    #T_183d790a_9d61_11ea_82cf_6432a86142f1 th:hover {
#           font-size: 12pt;
#     }    #T_183d790a_9d61_11ea_82cf_6432a86142f1 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col0 {
#             background-color:  #f29072;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col1 {
#             background-color:  #f39577;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col2 {
#             background-color:  #ef886b;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col3 {
#             background-color:  #e8765c;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col4 {
#             background-color:  #e97a5f;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col5 {
#             background-color:  #e46e56;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col6 {
#             background-color:  #ee8468;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col7 {
#             background-color:  #ec7f63;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col8 {
#             background-color:  #f29274;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col9 {
#             background-color:  #f08b6e;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col10 {
#             background-color:  #f18d6f;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col11 {
#             background-color:  #f29072;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col12 {
#             background-color:  #c0282f;
#             color:  #f1f1f1;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col13 {
#             background-color:  #ed8366;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col14 {
#             background-color:  #f39475;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col15 {
#             background-color:  #f39778;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col16 {
#             background-color:  #ee8669;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col17 {
#             background-color:  #ee8468;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col18 {
#             background-color:  #eb7d62;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col19 {
#             background-color:  #d55042;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col20 {
#             background-color:  #ea7b60;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col21 {
#             background-color:  #eb7d62;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col22 {
#             background-color:  #d65244;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col23 {
#             background-color:  #e67259;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col24 {
#             background-color:  #ed8366;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row0_col25 {
#             background-color:  #f7a889;
#             color:  #000000;
#             : ;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col1 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col2 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col3 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col4 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col5 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col6 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col7 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col8 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#             background-color:  transparent;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_183d790a_9d61_11ea_82cf_6432a86142f1row1_col9

# %% [markdown]
# Some closed malls (e.g., Shopping Morumbi) reported a mobiliy value greater than zero, which partially shows their strategy to sell on [drive thru](https://www1.folha.uol.com.br/mercado/2020/05/drive-thru-cresce-com-alternativa-de-shoppings-e-lojas-para-reduzir-perdas.shtml).
#
# The heatmaps show a more geographically diversified portfolio for brMalls. It has a bigger proportion of shopping centers in states softening quarantine measures, compared to Iguatemi - and this malls represent a relevant fraction of its revenues. This seems to be the main reason thath lead brMalls to retain more of its mobility.

# %% [markdown]
# ### How these values are calculated?
# The values showed above are the ratio between the historic mobility score and the current value collected for the period scrapping Google Maps. If value < 100, then the mobility score is beneath its usual value, if value > 100 then it's above its usual value (examples below)

# %%
# Example 1
def createList(string):
    
    output = pd.DataFrame({'usual':output_live0.T[string], 
                           'atual':output_live1.T[string]})
    
    return [string, output]

date_plot = '2020-05-20'
output_live1, output_live0 = byHour(tbdict, 'iguatemi', date_plot)

ncols = 4
nrows = ceil(len(output_live1) / 4)

fig, axs = plt.subplots(nrows, ncols, figsize = (20, 5 * nrows))
plt.subplots_adjust(wspace = 0.2, hspace = 0.4)
fig.suptitle(f"Iguatemi | {date_plot}", fontsize = 20, x=0.5, y=0.96, horizontalalignment = 'center', weight = 'bold')

flat_list = [item for sublist in axs for item in sublist]

for data, ax in zip([createList(x) for x in output_live0.index], flat_list):
    
    data[1].plot(y = 'usual', kind = 'bar', ax = ax, color = (1, 1, 1, 0.5), edgecolor = 'blue', linewidth = 1.5, ylim = (0, 110))
    data[1].plot(y = 'atual', kind = 'bar', ax = ax, color = (1, 0, 0.5, 0.5), ylim = (0, 110))
    
    ax.title.set_text(f'{data[0]}')

# %%
# Example 2
date_plot = '2020-05-20'
output_live1, output_live0 = byHour(tbdict, 'brmalls', date_plot)

ncols = 4
nrows = ceil(len(output_live1) / 4)

fig, axs = plt.subplots(nrows, ncols, figsize = (20, 5 * nrows))
plt.subplots_adjust(wspace = 0.2, hspace = 0.4)
fig.suptitle(f"brMalls | {date_plot}", fontsize = 20, x=0.5, y=0.92, horizontalalignment = 'center', weight = 'bold')

flat_list = [item for sublist in axs for item in sublist]

for data, ax in zip([createList(x) for x in output_live0.index], flat_list):
    
    data[1].plot(y = 'usual', kind = 'bar', ax = ax, color = (1, 1, 1, 0.5), edgecolor = 'blue', linewidth = 1.5, ylim = (0, 110))
    data[1].plot(y = 'atual', kind = 'bar', ax = ax, color = (1, 0, 0.5, 0.5), ylim = (0, 110))
    
    ax.title.set_text(f'{data[0]}')
